# %% [markdown]
# <a href="https://colab.research.google.com/github/Risqi2112/Penelitian/blob/main/Analisis_Sentimen_PPDB_2018_2022/Pengujian_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Open data

# %%
! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp:
    fp.write("""
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
""")
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:Risqi2112/Penelitian.git
# %cd /content/Penelitian
# Out:
# # github.com:22 SSH-2.0-babeld-181fb29f
# Cloning into 'Penelitian'...
# Warning: Permanently added the RSA host key for IP address '140.82.112.3' to the list of known hosts.
# remote: Enumerating objects: 309, done.
# remote: Counting objects: 100% (279/279), done.
# remote: Compressing objects: 100% (236/236), done.
# remote: Total 309 (delta 99), reused 139 (delta 41), pack-reused 30
# Receiving objects: 100% (309/309), 1.08 MiB | 3.76 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /content/Penelitian

# %%
import pandas as pd
data = pd.read_csv('/content/Penelitian/Analisis_Sentimen_PPDB_2018_2022/Data/Hasil/Preprocessing_Tanpa_Stopword.csv',encoding='utf-8',error_bad_lines=False)
data.head(), data.shape
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (  sentimen  tahun                                              tweet
#  0  Negatif   2018  jakarta terap sistem zonasi sekolah terima ser...
#  1  Negatif   2018  jakarta dipikirin demo ppdb pakai sistem zona ...
#  2  Negatif   2018  jalur afirmasi jakarta bukti rekening bank cal...
#  3  Negatif   2018  umum bangku kosong tahap jalur domisili daerah...
#  4  Negatif   2018  ppdb provinsi jateng ulas jalur afirmasi kjp j...,
#  (651, 3))

# %%
data.sentimen.replace(['Negatif','Netral','Positif'],[-1,0,1],inplace=True)
data.head()
# Out:
#    sentimen  tahun                                              tweet
# 0        -1   2018  jakarta terap sistem zonasi sekolah terima ser...
# 1        -1   2018  jakarta dipikirin demo ppdb pakai sistem zona ...
# 2        -1   2018  jalur afirmasi jakarta bukti rekening bank cal...
# 3        -1   2018  umum bangku kosong tahap jalur domisili daerah...
# 4        -1   2018  ppdb provinsi jateng ulas jalur afirmasi kjp j...

# %%
# Pembagian data_train & test_data
from sklearn.model_selection import train_test_split

seed = 99
testSize = 0.2

x_train, x_test, y_train, y_test = train_test_split(data["tweet"], data["sentimen"], 
                                                    test_size=testSize, random_state = seed)
x_train = x_train.values.astype('U')
x_test = x_test.values.astype('U')
y_train = y_train.values.astype('U')
y_test = y_test.values.astype('U')

print(x_train.shape, x_test.shape)
# Out:
# (520,) (131,)

# %%
#Tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer

vsm = TfidfVectorizer(lowercase=True, smooth_idf= True, sublinear_tf=True, 
                                   ngram_range=(1, 2), max_df=0.90, min_df=2)

x_train = vsm.fit_transform(x_train) # "Fit_Transform"
x_test = vsm.transform(x_test) # Perhatikan disini hanya "Transform"

print(x_train.shape, x_test.shape) # Jumlah kolom Sama ==> ini penting
# Out:
# (520, 1266) (131, 1266)

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn import svm

# %%
# Optimasi Hyperparameter/temukan parameter terbaik menggunakan gridCV
kCV = 10
metric = 'accuracy'
params = {}
params['tfidfvectorizer__min_df'] = [1, 2, 5, 10, 30]
params['tfidfvectorizer__max_df'] = [0.5, 0.75, 0.9, 0.95, 1.0]
params['tfidfvectorizer__smooth_idf'] = [True, False]
params['tfidfvectorizer__sublinear_tf'] = [True, False]
params['tfidfvectorizer__ngram_range'] = [(1, 1), (1, 2), (1,3)]
params['svc__C'] = [1, 5, 10] #sp.stats.uniform(scale=100)
params['svc__gamma'] = [0.1, 1, 10]
params['svc__kernel'] = ['rbf', 'sigmoid', 'linear', 'poly']
params['svc__decision_function_shape'] = ['ovo', 'ovr']

pipe = make_pipeline(TfidfVectorizer(), svm.SVC())
optSvm = GridSearchCV(pipe, params, cv=kCV, scoring=metric, verbose=2, n_jobs=-2) # refit=True, pre_dispatch='2*n_jobs' pre_dispatch min 2* n_jobs
optSvm.fit(x_train, y_train)
print(optSvm.best_score_)
print(optSvm.best_params_)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=linear, tfidfvectorizer__max_df=0.75, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# ...
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 216000 fits failed out of a total of 216000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 216000 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/usr/local/lib/python3.8/dist-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py", line 2077, in fit_transform
#     X = super().fit_transform(raw_documents)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py", line 1330, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py", line 1201, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py", line 113, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py", line 71, in _preprocess
#     doc = doc.lower()
#   File "/usr/local/lib/python3.8/dist-packages/scipy/sparse/base.py", line 687, in __getattr__
#     raise AttributeError(attr + " not found")
# AttributeError: lower not found
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan ... nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-992710d00593> in <module>
#      15 pipe = make_pipeline(TfidfVectorizer(), svm.SVC())
#      16 optSvm = GridSearchCV(pipe, params, cv=kCV, scoring=metric, verbose=2, n_jobs=-2) # refit=True, pre_dispatch='2*n_jobs' pre_dispatch min 2* n_jobs
# ---> 17 optSvm.fit(x_train, y_train)
#      18 print(optSvm.best_score_)
#      19 print(optSvm.best_params_)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     388         """
#     389         fit_params_steps = self._check_fit_params(**fit_params)
# --> 390         Xt = self._fit(X, y, **fit_params_steps)
#     391         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     392             if self._final_estimator != "passthrough":
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     346                 cloned_transformer = clone(transformer)
#     347             # Fit or load from cache the current transformer
# --> 348             X, fitted_transformer = fit_transform_one_cached(
#     349                 cloned_transformer,
#     350                 X,
#
# /usr/local/lib/python3.8/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2075         """
#    2076         self._check_params()
# -> 2077         X = super().fit_transform(raw_documents)
#    2078         self._tfidf.fit(X)
#    2079         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1328                     break
#    1329
# -> 1330         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1331
#    1332         if self.binary:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1199         for doc in raw_documents:
#    1200             feature_counter = {}
# -> 1201             for feature in analyze(doc):
#    1202                 try:
#    1203                     feature_idx = vocabulary[feature]
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     111     else:
#     112         if preprocessor is not None:
# --> 113             doc = preprocessor(doc)
#     114         if tokenizer is not None:
#     115             doc = tokenizer(doc)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in _preprocess(doc, accent_function, lower)
#      69     """
#      70     if lower:
# ---> 71         doc = doc.lower()
#      72     if accent_function is not None:
#      73         doc = accent_function(doc)
#
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/base.py in __getattr__(self, attr)
#     685             return self.getnnz()
#     686         else:
# --> 687             raise AttributeError(attr + " not found")
#     688
#     689     def transpose(self, axes=None, copy=False):
#
# AttributeError: lower not found

# %%
svm_score = optSvm.cv_results_['mean_test_score'][:10]
svm_score

# %%
# Algoritma SVM menggunakan parameter optimal
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

dSVM = svm.SVC()
dSVM.fit(x_train, y_train)
y_SVM = dSVM.predict(x_test)
print('Akurasi = ', accuracy_score(y_test, y_SVM))
print(confusion_matrix(y_test, y_SVM))
print(classification_report(y_test, y_SVM))

# %% [markdown]
# import seaborn as sns, matplotlib.pyplot as plt
#
# kCV = 10
# # Menggunakan parameter optimal
# svm_ = svm.SVC(C = 10, decision_function_shape= 'ovo', gamma = 0.1, kernel= 'rbf')
#
# models = ['SVM']
# svm_score = cross_val_score(svm_, x_train, y_train, cv=kCV, scoring='accuracy', n_jobs=-2, verbose=1)
# scores = [svm_score]
#
# data = {m:s for m,s in zip(models, scores)}
# for name in data.keys():
#     print("Accuracy %s: %0.2f (+/- %0.2f)" % (name, data[name].mean(), data[name].std() * 2))
#
# sns.boxplot(data=pd.DataFrame(data), orient='h')
# plt.show()
