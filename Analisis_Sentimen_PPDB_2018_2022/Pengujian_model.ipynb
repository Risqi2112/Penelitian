# %% [markdown]
# <a href="https://colab.research.google.com/github/Risqi2112/Penelitian/blob/main/Analisis_Sentimen_PPDB_2018_2022/Pengujian_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Open data

# %%
! mkdir -p /root/.ssh
with open("/root/.ssh/id_rsa", mode="w") as fp:
    fp.write("""
-----BEGIN RSA PRIVATE KEY-----

-----END RSA PRIVATE KEY-----
""")
! ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
! chmod go-rwx /root/.ssh/id_rsa
! git clone git@github.com:Risqi2112/Penelitian.git
# %cd /content/Penelitian
# Out:
# # github.com:22 SSH-2.0-babeld-181fb29f
# Cloning into 'Penelitian'...
# Warning: Permanently added the RSA host key for IP address '140.82.113.4' to the list of known hosts.
# remote: Enumerating objects: 364, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 364 (delta 9), reused 0 (delta 0), pack-reused 331
# Receiving objects: 100% (364/364), 1.27 MiB | 3.81 MiB/s, done.
# Resolving deltas: 100% (126/126), done.
# /content/Penelitian

# %%
import pandas as pd
data = pd.read_csv('/content/Penelitian/Analisis_Sentimen_PPDB_2018_2022/Data/Hasil/Preprocessing_Tanpa_Stopword.csv',encoding='utf-8',error_bad_lines=False)
data.head(), data.shape
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (  sentimen  tahun                                              tweet
#  0  Negatif   2018  jakarta penerapan sistem zonasi sekolah peneri...
#  1  Negatif   2018  jakarta dipikirin demo ppdb pakai sistem zona ...
#  2  Negatif   2018  jalur afirmasi jakarta dibuktikan rekening ban...
#  3  Negatif   2018  pengumuman bangku kosong tahap jalur domisili ...
#  4  Negatif   2018  ppdb provinsi jateng diulas jalur afirmasi kjp...,
#  (651, 3))

# %%
data.sentimen.replace(['Negatif','Netral','Positif'],[-1,0,1],inplace=True)
data.head()
# Out:
#    sentimen  tahun                                              tweet
# 0        -1   2018  jakarta penerapan sistem zonasi sekolah peneri...
# 1        -1   2018  jakarta dipikirin demo ppdb pakai sistem zona ...
# 2        -1   2018  jalur afirmasi jakarta dibuktikan rekening ban...
# 3        -1   2018  pengumuman bangku kosong tahap jalur domisili ...
# 4        -1   2018  ppdb provinsi jateng diulas jalur afirmasi kjp...

# %%
# Pembagian data_train & test_data
from sklearn.model_selection import train_test_split

seed = 99
testSize = 0.2

x_train, x_test, y_train, y_test = train_test_split(data["tweet"], data["sentimen"], 
                                                    test_size=testSize, random_state = seed)
x_train = x_train.values.astype('U')
x_test = x_test.values.astype('U')
y_train = y_train.values.astype('U')
y_test = y_test.values.astype('U')

print(x_train.shape, x_test.shape)
# Out:
# (520,) (131,)

# %%
#Tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer

vsm = TfidfVectorizer(lowercase=True, smooth_idf= True, sublinear_tf=True, 
                                   ngram_range=(1, 2), max_df=0.90, min_df=2)

x_train = vsm.fit_transform(x_train) # "Fit_Transform"
x_test = vsm.transform(x_test) # Perhatikan disini hanya "Transform"

print(x_train.shape, x_test.shape) # Jumlah kolom Sama ==> ini penting
# Out:
# (520, 1249) (131, 1249)

# %%
# Algoritma SVM
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

dSVM = svm.SVC()
dSVM.fit(x_train, y_train)
y_SVM = dSVM.predict(x_test)
print('Akurasi = ', accuracy_score(y_test, y_SVM))
print(confusion_matrix(y_test, y_SVM))
print(classification_report(y_test, y_SVM))
# Out:
# Akurasi =  0.6335877862595419
# [[30  0 18]
#  [ 6 30 16]
#  [ 5  3 23]]
#               precision    recall  f1-score   support
#
#           -1       0.73      0.62      0.67        48
#            0       0.91      0.58      0.71        52
#            1       0.40      0.74      0.52        31
#
#     accuracy                           0.63       131
#    macro avg       0.68      0.65      0.63       131
# weighted avg       0.72      0.63      0.65       131

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn import svm

# %%
seed = 99
testSize = 0.2

x_train, x_test, y_train, y_test = train_test_split(data["tweet"], data["sentimen"], 
                                                    test_size=testSize, random_state = seed)
x_train = x_train.values.astype('U')
x_test = x_test.values.astype('U')
y_train = y_train.values.astype('U')
y_test = y_test.values.astype('U')

# %%
# Optimasi Hyperparameter/temukan parameter terbaik menggunakan gridCV
kCV = 2
metric = 'accuracy'
params = {}
params['tfidfvectorizer__min_df'] = [1, 2, 5, 10, 30]
params['tfidfvectorizer__max_df'] = [0.5, 0.75, 0.9, 0.95, 1.0]
params['tfidfvectorizer__smooth_idf'] = [True, False]
params['tfidfvectorizer__sublinear_tf'] = [True, False]
params['tfidfvectorizer__ngram_range'] = [(1, 1), (1, 2), (1,3)]
params['svc__C'] = [1, 5, 10] #sp.stats.uniform(scale=100)
params['svc__gamma'] = [0.1, 1, 10]
params['svc__kernel'] = ['rbf', 'sigmoid', 'linear', 'poly']
params['svc__decision_function_shape'] = ['ovo', 'ovr']

pipe = make_pipeline(TfidfVectorizer(), svm.SVC())
optSvm = GridSearchCV(pipe, params, cv=kCV, scoring=metric, verbose=2, n_jobs=-2) # refit=True, pre_dispatch='2*n_jobs' pre_dispatch min 2* n_jobs
optSvm.fit(x_train, y_train)
print(optSvm.best_score_)
print(optSvm.best_params_)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=0.95, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=2, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=0.1, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# ...
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=True, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END svc__C=10, svc__decision_function_shape=ovr, svc__gamma=10, svc__kernel=poly, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=30, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__smooth_idf=False, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# 0.675
# {'svc__C': 1, 'svc__decision_function_shape': 'ovo', 'svc__gamma': 1, 'svc__kernel': 'rbf', 'tfidfvectorizer__max_df': 0.5, 'tfidfvectorizer__min_df': 2, 'tfidfvectorizer__ngram_range': (1, 2), 'tfidfvectorizer__smooth_idf': True, 'tfidfvectorizer__sublinear_tf': False}

# %%
svm_score = optSvm.cv_results_['mean_test_score'][:10]
svm_score
# Out:
# array([0.40769231, 0.40769231, 0.40576923, 0.40576923, 0.40576923,
#        0.40576923, 0.40576923, 0.40576923, 0.40576923, 0.40576923])

# %%
#Tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer

vsm = TfidfVectorizer(lowercase=True, smooth_idf= True, sublinear_tf=True, 
                                   ngram_range=(1, 2), max_df=0.90, min_df=2)

x_train = vsm.fit_transform(x_train) # "Fit_Transform"
x_test = vsm.transform(x_test) # Perhatikan disini hanya "Transform"

print(x_train.shape, x_test.shape) # Jumlah kolom Sama ==> ini penting
# Out:
# (520, 1249) (131, 1249)

# %%
# Algoritma SVM menggunakan parameter optimal
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

dSVM = svm.SVC(C=1,decision_function_shape='ovo',gamma=1,kernel='rbf')
dSVM.fit(x_train, y_train)
y_SVM = dSVM.predict(x_test)
print('Akurasi = ', accuracy_score(y_test, y_SVM))
print(confusion_matrix(y_test, y_SVM))
print(classification_report(y_test, y_SVM))
# Out:
# Akurasi =  0.6335877862595419
# [[30  0 18]
#  [ 6 30 16]
#  [ 5  3 23]]
#               precision    recall  f1-score   support
#
#           -1       0.73      0.62      0.67        48
#            0       0.91      0.58      0.71        52
#            1       0.40      0.74      0.52        31
#
#     accuracy                           0.63       131
#    macro avg       0.68      0.65      0.63       131
# weighted avg       0.72      0.63      0.65       131

# %% [markdown]
# import seaborn as sns, matplotlib.pyplot as plt
#
# kCV = 10
# # Menggunakan parameter optimal
# svm_ = svm.SVC(C = 10, decision_function_shape= 'ovo', gamma = 0.1, kernel= 'rbf')
#
# models = ['SVM']
# svm_score = cross_val_score(svm_, x_train, y_train, cv=kCV, scoring='accuracy', n_jobs=-2, verbose=1)
# scores = [svm_score]
#
# data = {m:s for m,s in zip(models, scores)}
# for name in data.keys():
#     print("Accuracy %s: %0.2f (+/- %0.2f)" % (name, data[name].mean(), data[name].std() * 2))
#
# sns.boxplot(data=pd.DataFrame(data), orient='h')
# plt.show()
